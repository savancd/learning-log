# %%
import json
import plotly.graph_objects as go

# %%
with open("life.json", "r", encoding="utf-8") as f:
    life = json.load(f)

# %%
with open("locations.json", "r", encoding="utf-8") as f:
    locations = json.load(f)

# %%
# Extracting data


year = []
work = []
money = []
family = []
traveling = []
physical_work = []
gym = []
windows = []
linux = []
python = []
location_id = []
event = []

for e in life:
    year.append(e["year"])
    work.append(e["work"])
    money.append(e["money"])
    family.append(e["family"])
    traveling.append(e["traveling"])
    physical_work.append(e["physical_work"])
    gym.append(e["gym"])
    windows.append(e["windows"])
    linux.append(e["linux"])
    python.append(e["python"])
    event.append("event")
    location_id.append("location_id")

    
print(year, work, money)
# Out:
# ['2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024', '2025', '2026'] ['10', '8', '10', '10', '10', '10', '0', '10', '10', '10', '10', '10', '8', '0', '10', '10', '10', '0', '10', ''] ['10', '8', '5', '6', '8', '9', '3', '5', '10', '10', '10', '8', '6', '2', '6', '4', '5', '2', '4', '']

# %%
life
# Out:
# [{'year': '2005',
#   'work': '10',
#   'money': '10',
#   'family': '10',
#   'traveling': '3',
#   'physical_work': '10',
#   'gym': '0',
#   'windows': '5',
#   'linux': '0',
#   'python': '0',
#   'location_id': 'loc_1',
#   'event': 'Just normal life, working, playing with tech, making .bat files as viruses and destroying my own computer '},
#  {'year': '2006',
#   'work': '8',
#   'money': '8',
#   'family': '2',
#   'traveling': '1',
#   'physical_work': '10',
#   'gym': '0',
#   'windows': '3',
#   'linux': '0',
#   'python': '0',
#   'location_id': 'loc_1',
#   'event': 'Problems with health family issues '},
#  {'year': '2007',
#   'work': '10',
#   'money': '5',
#   'family': '3',
#   'traveling': '0',
#   'physical_work': '10',
#   'gym': '0',
#   'windows': '0',
#   'linux': '0',
#   'python': '0',
#   'location_id': 'loc_1',
#   'event': 'none'},
#  {'year': '2008',
#   'work': '10',
#   'money': '6',
#   'family': '5',
#   'traveling': '0',
#   'physical_work': '10',
# ...
