# %%
import json

# %%
with open("/data/repo-learning/computer-Science-and-Software-Engineering/real-estate-vis/datasets/raw/2026/overpass-turbo/data/24.06.2026/highway_motorway_link.geojson", "r", encoding="utf-8") as file:
	data = json.load(file)

# %% [markdown]
# <h3>The list of keys</h3>

# %%
print(data.keys())
# Out:
# dict_keys(['type', 'generator', 'copyright', 'timestamp', 'features'])

# %%
print(data["type"])
# Out:
# FeatureCollection

# %%
len(data["features"])
# Out:
# 12099

# %% [markdown]
# <h3>Targeting feature inside list with a possition of 0</h3>

# %%
data["features"][0]
# Out:
# {'type': 'Feature',
#  'properties': {'@id': 'way/2667097',
#   'highway': 'primary',
#   'lanes': '2',
#   'lit': 'yes',
#   'maxheight': '4.27',
#   'maxspeed': '60',
#   'maxspeed:bus': '50',
#   'maxspeed:hgv': '50',
#   'name': 'Taft Avenue',
#   'name:es': 'Avenida Taft',
#   'name:etymology': 'William Howard Taft',
#   'name:etymology:wikidata': 'Q35648',
#   'name:tl': 'Abenida Taft',
#   'oneway': 'yes',
#   'ref': '170',
#   'sidewalk': 'right',
#   'source:maxspeed': 'sign',
#   'surface': 'concrete'},
#  'geometry': {'type': 'LineString',
#   'coordinates': [[120.9967123, 14.5562681],
#    [120.9966989, 14.5563258],
#    [120.9966061, 14.5567242],
#    [120.9965407, 14.5570051],
#    [120.9964395, 14.5574398],
#    [120.9964325, 14.5574769],
#    [120.9963185, 14.5579591],
#    [120.9962467, 14.5582675],
#    [120.9961433, 14.5587115],
#    [120.9961282, 14.5587765]]},
#  'id': 'way/2667097'}

# %%
for i in data:
    print(i["features"][0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 2
#       1 for i in data:
# ----> 2     print(i["features"][0])
#
# TypeError: string indices must be integers, not 'str'
