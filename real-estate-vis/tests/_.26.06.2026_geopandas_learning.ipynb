# %% [markdown]
# # Introduction to geopandas

# %%
# First to import library

import os
import geopandas as gdp
from geodatasets import get_path

# %%
# checking the version

gpd.__version__
# Out:
# '1.1.3'

# %%
gpd.datasets.available
# Out:
# []

# %%
# getting data

gdf = gdp.read_file("datasets/raw/2026/overpass-turbo/data/26.06.2026/admin_boundaries_motorway_link_26.geojson")

# %%
# printing data to the screen

gdf.head()
# Out:
#                 id              @id admin_level admin_subdivisions  \
# 0  relation/103703  relation/103703           6                NaN
# 1  relation/103704  relation/103704           8                NaN
# 2  relation/103706  relation/103706           8                NaN
# 3  relation/103707  relation/103707           8                NaN
# 4  relation/103716  relation/103716           6                NaN
#
#   admin_type:PH     alt_name  alt_name:en alt_name:tl            border_type  \
# 0           NaN          NaN          NaN         NaN                    NaN
# 1           NaN          NaN          NaN         NaN                    NaN
# 2           NaN          NaN          NaN         NaN                    NaN
# 3           NaN          NaN          NaN         NaN                    NaN
# 4           NaN  Makati City  Makati City         NaN  highly_urbanized_city
#
#          boundary  ...                                  source:population  \
# ...

# %%
gdf.plot()
# Out:
# <Axes: >

# %%
type(gdf)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
#gdf.tail(3)

# %%
len(gdf)
# Out:
# 170

# %% [markdown]
# ## Printing keys:

# %%
gdf.keys()
# Out:
# Index(['id', '@id', 'admin_level', 'admin_subdivisions', 'admin_type:PH',
#        'alt_name', 'alt_name:en', 'alt_name:tl', 'border_type', 'boundary',
#        ...
#        'source:population', 'source:start_date', 'start_date', 'type',
#        '@relations', 'website', 'wikidata', 'wikimedia_commons', 'wikipedia',
#        'geometry'],
#       dtype='str', length=216)

# %% [markdown]
# ## Check geometry type and CRS #
#
# After reading the file, inspect geometry types and coordinate reference system:

# %%
gdf.geom_type.unique()
gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
# it can be printed as well in for loop
for n, key in enumerate(gdf.keys()):
    #key_s = key["name"]
    print(n, key)
# Out:
# 0 id
# 1 @id
# 2 admin_level
# 3 admin_subdivisions
# 4 admin_type:PH
# 5 alt_name
# 6 alt_name:en
# 7 alt_name:tl
# 8 border_type
# 9 boundary
# 10 fixme
# 11 is_in:city
# 12 land_area
# 13 name
# 14 name:ace
# 15 name:af
# 16 name:als
# 17 name:am
# 18 name:an
# 19 name:ang
# 20 name:ar
# 21 name:arz
# 22 name:ast
# 23 name:az
# 24 name:azb
# 25 name:ba
# 26 name:bcl
# 27 name:be
# 28 name:be-tarask
# 29 name:bg
# 30 name:bn
# 31 name:bo
# 32 name:br
# 33 name:bs
# 34 name:bxr
# 35 name:ca
# 36 name:cbk-zam
# 37 name:cdo
# 38 name:ce
# 39 name:ceb
# 40 name:ckb
# 41 name:crh
# 42 name:cs
# 43 name:cv
# 44 name:cy
# 45 name:da
# 46 name:de
# 47 name:diq
# 48 name:dsb
# 49 name:dty
# 50 name:el
# 51 name:en
# 52 name:eo
# 53 name:es
# 54 name:et
# 55 name:eu
# 56 name:fa
# 57 name:fi
# 58 name:fo
# 59 name:fr
# 60 name:frr
# 61 name:fy
# 62 name:ga
# 63 name:gd
# 64 name:gl
# 65 name:ha
# 66 name:hak
# 67 name:he
# 68 name:hi
# 69 name:hif
# 70 name:hr
# 71 name:hsb
# 72 name:ht
# ...

# %%
gdf.columns
# Out:
# Index(['id', '@id', 'admin_level', 'admin_subdivisions', 'admin_type:PH',
#        'alt_name', 'alt_name:en', 'alt_name:tl', 'border_type', 'boundary',
#        ...
#        'source:population', 'source:start_date', 'start_date', 'type',
#        '@relations', 'website', 'wikidata', 'wikimedia_commons', 'wikipedia',
#        'geometry'],
#       dtype='str', length=216)

# %%
# Targeting specific keys

cols = ["id", "admin_type:PH", "alt_name", "geometry", "source:population"]

for n in cols:
    print(n)
    print(gdf[n])
# Out:
# id
# 0      relation/103703
# 1      relation/103704
# 2      relation/103706
# 3      relation/103707
# 4      relation/103716
#             ...
# 165    node/6343962679
# 166    node/6343962681
# 167    node/6344005936
# 168    node/6344005930
# 169    node/6344005937
# Name: id, Length: 170, dtype: str
# admin_type:PH
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 165    NaN
# 166    NaN
# 167    NaN
# 168    NaN
# 169    NaN
# Name: admin_type:PH, Length: 170, dtype: str
# alt_name
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4      Makati City
#           ...
# 165            NaN
# 166            NaN
# 167            NaN
# 168            NaN
# 169            NaN
# Name: alt_name, Length: 170, dtype: str
# geometry
# 0      MULTIPOLYGON (((121.02209 14.56617, 121.02241 ...
# 1      POLYGON ((120.9931 14.57813, 120.99299 14.5780...
# 2      POLYGON ((120.9921 14.57772, 120.99215 14.5777...
# ...
